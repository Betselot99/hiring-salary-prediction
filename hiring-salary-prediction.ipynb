# %% [markdown]
# <a href="https://colab.research.google.com/github/Betselot99/hiring-salary-prediction/blob/main/hiring-salary-prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Betselot Berhanu WTF/2025/8987**

# %%
#Importing panda library and integrating google drive
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Removes warnings
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = '/content/drive/MyDrive//hiring.csv'  # Update if needed, e.g., if filename is 'hiring (1).csv'
df = pd.read_csv(file_path)

# Display the original data
print("Original Data:")
print(df)
# Out:
# Original Data:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# Preprocess the data
# Define mapping for experience words to numbers
word_to_num = {
    'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4,
    'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9,
    'ten': 10, 'eleven': 11, 'twelve': 12, 'thirteen': 13,
    'fourteen': 14, 'fifteen': 15
}

# Convert experience to numbers, fill blanks with 0
df['experience'] = df['experience'].map(word_to_num).fillna(0)

# Fill missing test scores with mean
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].mean())

# Display cleaned data
print("\nCleaned Data:")
print(df)
# Out:
# Cleaned Data:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         0.0               8.000000                           9      50000
# 1         0.0               8.000000                           6      45000
# 2         5.0               6.000000                           7      60000
# 3         2.0              10.000000                          10      65000
# 4         7.0               9.000000                           6      70000
# 5         3.0               7.000000                          10      62000
# 6        10.0               7.857143                           7      72000
# 7        11.0               7.000000                           8      80000

# %%
# Prepare features and target
X = df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']]
y = df['salary($)']

# Train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict for the new candidates
candidates = np.array([
    [2, 9, 6],   # 2 yr experience, 9 test score, 6 interview score
    [12, 10, 10] # 12 yr experience, 10 test score, 10 interview score
])
predictions = model.predict(candidates)

# Display predictions
print("\nPredicted Salaries:")
print(f"Candidate 1 (2 yr exp, 9 test, 6 interview): ${predictions[0]:.2f}")
print(f"Candidate 2 (12 yr exp, 10 test, 10 interview): ${predictions[1]:.2f}")
# Out:
# Predicted Salaries:
# Candidate 1 (2 yr exp, 9 test, 6 interview): $53290.89
# Candidate 2 (12 yr exp, 10 test, 10 interview): $92268.07
